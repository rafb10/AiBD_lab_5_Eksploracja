# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:\\Users\\rafal\\Downloads\\VII semestr\\Analiza_i_BazyDanych\\lab1\\Command Files\\final_data.xlsx")

# %%
data.head()
# Out:
#       Albania  Argentina  Armenia  Australia  Austria  Azerbaijan  Belarus  \
# 1952       -9         -9       -9         10       10          -9       -9
# 1957       -9         -1       -7         10       10          -7       -7
# 1962       -9         -1       -7         10       10          -7       -7
# 1967       -9         -9       -7         10       10          -7       -7
# 1972       -9         -9       -7         10       10          -7       -7
#
#       Belgium  Bhutan  Bolivia    ...      Tajikistan  Thailand  Turkey  \
# 1952       10     -10       -4    ...              -9        -6       7
# 1957       10     -10       -3    ...              -7        -3       4
# 1962       10     -10       -3    ...              -7        -7       9
# 1967       10     -10       -4    ...              -7        -7       8
# 1972       10     -10       -7    ...              -7        -7      -2
#
#       Turkmenistan  Ukraine  United Kingdom  United States  Uruguay  \
# ...

# %%
data.describe()
# Out:
#         Albania  Argentina   Armenia  Australia  Austria  Azerbaijan  \
# count  9.000000   9.000000  9.000000        9.0      9.0    9.000000
# mean  -7.444444  -3.444444 -5.666667       10.0     10.0   -6.333333
# std    4.666667   7.037597  4.795832        0.0      0.0    2.828427
# min   -9.000000  -9.000000 -9.000000       10.0     10.0   -9.000000
# 25%   -9.000000  -9.000000 -7.000000       10.0     10.0   -7.000000
# 50%   -9.000000  -8.000000 -7.000000       10.0     10.0   -7.000000
# 75%   -9.000000  -1.000000 -7.000000       10.0     10.0   -7.000000
# max    5.000000   8.000000  7.000000       10.0     10.0    1.000000
#
#         Belarus  Belgium  Bhutan   Bolivia    ...      Tajikistan  Thailand  \
# count  9.000000      9.0     9.0  9.000000    ...        9.000000  9.000000
# mean  -5.666667     10.0   -10.0 -0.222222    ...       -7.111111 -2.111111
# std    4.795832      0.0     0.0  6.833333    ...        0.781736  5.532731
# ...

# %%
import matplotlib.pyplot as plt

# %%
dt2 = data.loc[:,['Poland']] 
hist = dt2.hist()

# %%
dt2.plot(kind = 'bar')

# %%
plt.show()
